# %%
# %%capture robo_log
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="xASvrfOl0QmZenRAZDB1")
project = rf.workspace("learning-eri4b").project("plant-disease-tmyq8")
dataset = project.version(3).download("yolov8", location="/content/datasets/Plants")

# %%
# %%capture
# !pip install ultralytics

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt')
results = model.train(data='datasets/Plants/data.yaml', epochs=60, imgsz=640)
# Out:
# Ultralytics YOLOv8.0.235 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import locale
print(locale.getpreferredencoding())

import locale
def getpreferredencoding(do_setlocale = True):
  return "UTF-8"
locale.getpreferredencoding = getpreferredencoding
# Out:
# ANSI_X3.4-1968

# %%
# !cp -r /content/datasets /content/drive/MyDrive/Colab\ Notebooks/
