# %%
# %%capture robo_log
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="xASvrfOl0QmZenRAZDB1")
project = rf.workspace("learning-eri4b").project("plant-disease-tmyq8")
dataset = project.version(3).download("yolov8", location="/content/datasets/Plants")

# %%
# %%capture
# !pip install ultralytics

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt')
results = model.train(data='datasets/Plants/data.yaml', epochs=60, imgsz=640)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import locale
print(locale.getpreferredencoding())

import locale
def getpreferredencoding(do_setlocale = True):
  return "UTF-8"
locale.getpreferredencoding = getpreferredencoding
# Out:
# ANSI_X3.4-1968

# %%
# !cp -r /content/datasets /content/drive/MyDrive/Colab\ Notebooks/
# Out:
# cp: cannot stat '/content/datasets': No such file or directory

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.pt')  # load an official model
model = YOLO('/content/drive/MyDrive/Colab Notebooks/runs/detect/train/weights/best.pt')  # load a custom model

# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO('/content/drive/MyDrive/Colab Notebooks/runs/detect/train/weights/best.pt')
model.predict('/content/drive/MyDrive/Colab Notebooks/datasets/Plants/test/images/bercak_daun--104-_JPG.rf.5ff566270fec5dbdfa221397e2221438.jpg', save=True, imgsz=640, conf=0.1)
# Out:
# image 1/1 /content/drive/MyDrive/Colab Notebooks/datasets/Plants/test/images/bercak_daun--104-_JPG.rf.5ff566270fec5dbdfa221397e2221438.jpg: 640x640 (no detections), 7.3ms
# Speed: 2.0ms preprocess, 7.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'bercak_daun', 1: 'defisiensi_kalsium', 2: 'hangus_daun', 3: 'hawar_daun', 4: 'mosaik_vena_kuning', 5: 'virus_kuning_keriting'}
#  obb: None
#  orig_img: array([[[168, 168, 174],
#          [167, 167, 173],
#          [166, 166, 172],
#          ...,
#          [160, 159, 163],
#          [160, 159, 163],
#          [160, 159, 163]],
#
#         [[167, 167, 173],
#          [167, 167, 173],
#          [166, 166, 172],
#          ...,
#          [160, 159, 163],
#          [160, 159, 163],
#          [160, 159, 163]],
#
# ...

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO('/content/drive/MyDrive/Colab Notebooks/runs/detect/train/weights/best.pt')
results = model(['/content/drive/MyDrive/Colab Notebooks/datasets/Plants/test/images/bercak_daun--191-_JPG.rf.058118a2f20bc1984470e928626c3318.jpg', '/content/drive/MyDrive/Colab Notebooks/datasets/Plants/test/images/bercak_daun--131-_JPG.rf.d37f5235347de09fa696af52dc035a5b.jpg','/content/drive/MyDrive/Colab Notebooks/datasets/Plants/test/images/bercak_daun--308-_JPG.rf.0941c8e1840c3c7e26eb4fb22b244a87.jpg','/content/drive/MyDrive/Colab Notebooks/datasets/Plants/test/images/defisiensi_kalsium--355-_jpg.rf.37e3bfee39b1808ff937e21008f337b0.jpg'],save=True, imgsz=640, conf=0.1)
# Out:
# 0: 640x640 5 bercak_dauns, 1: 640x640 7 bercak_dauns, 2: 640x640 5 bercak_dauns, 3: 640x640 6 defisiensi_kalsiums, 22.1ms
# Speed: 2.4ms preprocess, 5.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict3

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO('/content/drive/MyDrive/Colab Notebooks/runs/detect/train/weights/best.pt')
results = model('/content/images.jpeg',save=True, imgsz=640, conf=0.1)
# Out:
# image 1/1 /content/images.jpeg: 480x640 1 hangus_daun, 184.9ms
# Speed: 7.8ms preprocess, 184.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict4

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO('/content/drive/MyDrive/Colab Notebooks/runs/detect/train/weights/best.pt')
results = model('/content/vecteezy_different-is-amazingly-beautiful_24842666.mp4',save=True, imgsz=640, conf=0.4)

# %%
model = YOLO('/content/drive/MyDrive/Colab Notebooks/runs/detect/train/weights/best.pt')
results = model('/content/video.mp4',save=True, imgsz=640, conf=0.4)

# %%
from ultralytics import YOLO
model = YOLO('/content/drive/MyDrive/Colab Notebooks/runs/detect/train/weights/best.pt')
results = model('/content/3.mp4',save=True, imgsz=640, conf=0.1)
